# %% [markdown]
# ### Importar bibliotecas

# %%
# Instalar 
#pip install mysql-connector-python
#pip install xmltodict
# Out:
#   Cell In[5], line 2
#     pip install xmltodict
#         ^
# SyntaxError: invalid syntax

# %%
import sqlite3
import pandas as pd
import mysql.connector as sql

# %%
# load data
df = pd.read_csv('logs.csv')
df.head()
# Out:
#                  Fecha    Tipo    Device             Link
# 0  2024-06-01 12:00:01    INFO   Router1          Link Up
# 1  2024-06-01 12:05:42   ERROR   Router2        Link Down
# 2  2024-06-01 12:07:55    WARN   Switch3   High CPU Usage
# 3  2024-06-01 12:10:00    INFO   Router1        Link Down
# 4  2024-06-01 12:15:10    INFO   Router2          Link Up

# %%
df.columns
# Out:
# Index(['Fecha', ' Tipo', ' Device', ' Link'], dtype='object')

# %%
# Clean data
df.columns = df.columns.str.strip()

# %%
df.columns
# Out:
# Index(['Fecha', 'Tipo', 'Device', 'Link'], dtype='object')

# %%
# Create SQLite database
connection = sqlite3.connect('demo.db')

# %%
# Create table and Load data file to SQLite
df.to_sql('logs',connection, if_exists='replace')
# Out:
# 10

# %%
# Close connection
connection.close
# Out:
# <function Connection.close()>
